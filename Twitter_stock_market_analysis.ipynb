# %% [markdown]
# <a href="https://colab.research.google.com/github/adammoley27/data-science/blob/main/Twitter_stock_market_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2013-11-07  45.099998  50.090000  44.000000  44.900002  44.900002
# 1    2013-11-08  45.930000  46.939999  40.685001  41.650002  41.650002
# 2    2013-11-11  40.500000  43.000000  39.400002  42.900002  42.900002
# 3    2013-11-12  43.660000  43.779999  41.830002  41.900002  41.900002
# 4    2013-11-13  41.029999  42.869999  40.759998  42.599998  42.599998
# ...         ...        ...        ...        ...        ...        ...
# 2259 2022-10-28        NaN        NaN        NaN        NaN        NaN
# 2260 2022-10-31        NaN        NaN        NaN        NaN        NaN
# 2261 2022-11-01        NaN        NaN        NaN        NaN        NaN
# 2262 2022-11-02        NaN        NaN        NaN        NaN        NaN
# 2263 2022-11-03        NaN        NaN        NaN        NaN        NaN
#
#            Volume
# 0     117701670.0
# 1      27925307.0
# 2      16113941.0
# 3       6316755.0
# 4       8688325.0
# ...           ...
# 2259          NaN
# 2260          NaN
# 2261          NaN
# 2262          NaN
# 2263          NaN
#
# [2264 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_486068955418779379 = autoviz.get_df('df_486068955418779379')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_486068955418779379, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5009964876106645483 = autoviz.get_df('df_5009964876106645483')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5009964876106645483, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7970263776505971222 = autoviz.get_df('df_7970263776505971222')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7970263776505971222, *['Low'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_838993544501935947 = autoviz.get_df('df_838993544501935947')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_838993544501935947, *['Close'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3869352043627772461 = autoviz.get_df('df_3869352043627772461')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3869352043627772461, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2957615983530429036 = autoviz.get_df('df_2957615983530429036')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2957615983530429036, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2087957686218475476 = autoviz.get_df('df_2087957686218475476')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2087957686218475476, *['Low'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7191793244758751367 = autoviz.get_df('df_7191793244758751367')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_7191793244758751367, *['Close'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2715851587000420451 = autoviz.get_df('df_2715851587000420451')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_2715851587000420451, *[[['Open', 'High'], ['High', 'Low'], ['Low', 'Close'], ['Close', 'Adj Close']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3473191975387173901 = autoviz.get_df('df_3473191975387173901')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_3473191975387173901, *['Date', 'Open', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8780153909412879609 = autoviz.get_df('df_8780153909412879609')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8780153909412879609, *['Date', 'High', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8248388339733906679 = autoviz.get_df('df_8248388339733906679')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_8248388339733906679, *['Date', 'Low', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_1716192014153751380 = autoviz.get_df('df_1716192014153751380')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_1716192014153751380, *['Date', 'Close', None], **{})
# chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np # linear algebra
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

path="/content/drive/MyDrive/TWTR.csv"
df= pd.read_csv(path)


df.describe
# Out:
# <bound method NDFrame.describe of             Date       Open       High        Low      Close  Adj Close  \
# 0      11/7/2013  45.099998  50.090000  44.000000  44.900002  44.900002
# 1      11/8/2013  45.930000  46.939999  40.685001  41.650002  41.650002
# 2     11/11/2013  40.500000  43.000000  39.400002  42.900002  42.900002
# 3     11/12/2013  43.660000  43.779999  41.830002  41.900002  41.900002
# 4     11/13/2013  41.029999  42.869999  40.759998  42.599998  42.599998
# ...          ...        ...        ...        ...        ...        ...
# 2259  10/28/2022        NaN        NaN        NaN        NaN        NaN
# 2260  10/31/2022        NaN        NaN        NaN        NaN        NaN
# 2261   11/1/2022        NaN        NaN        NaN        NaN        NaN
# 2262   11/2/2022        NaN        NaN        NaN        NaN        NaN
# 2263   11/3/2022        NaN        NaN        NaN        NaN        NaN
#
#            Volume
# 0     117701670.0
# 1      27925307.0
# 2      16113941.0
# 3       6316755.0
# 4       8688325.0
# ...           ...
# 2259          NaN
# 2260          NaN
# 2261          NaN
# 2262          NaN
# 2263          NaN
#
# [2264 rows x 7 columns]>

# %% [markdown]
# # Data exploration

# %%
df.shape
# Out:
# (2264, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2264 non-null   object
#  1   Open       2259 non-null   float64
#  2   High       2259 non-null   float64
#  3   Low        2259 non-null   float64
#  4   Close      2259 non-null   float64
#  5   Adj Close  2259 non-null   float64
#  6   Volume     2259 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 123.9+ KB

# %%
df.isna().sum()
# Out:
# Date         0
# Open         5
# High         5
# Low          5
# Close        5
# Adj Close    5
# Volume       5
# dtype: int64

# %%
df['Open'].fillna(df['Open'].mean(), inplace=True)
df['High'].fillna(df['High'].mean(), inplace=True)
df['Low'].fillna(df['Low'].mean(), inplace=True)
df['Close'].fillna(df['Close'].mean(), inplace=True)
df['Adj Close'].fillna(df['Adj Close'].mean(), inplace=True)
df['Volume'].fillna(df['Volume'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#             count          mean           std     min           25%  \
# Open       2259.0  3.602029e+01  1.411846e+01  13.950  2.555000e+01
# High       2259.0  3.669988e+01  1.437206e+01  14.220  2.621500e+01
# Low        2259.0  3.533946e+01  1.382872e+01  13.725  2.491250e+01
# Close      2259.0  3.600363e+01  1.408999e+01  14.010  2.541000e+01
# Adj Close  2259.0  3.600363e+01  1.408999e+01  14.010  2.541000e+01
# Volume     2259.0  2.175186e+07  1.909988e+07   0.000  1.233530e+07
#
#                     50%           75%           max
# Open       3.542000e+01  4.420500e+01  7.836000e+01
# High       3.610000e+01  4.501500e+01  8.075000e+01
# Low        3.482000e+01  4.332750e+01  7.605000e+01
# Close      3.549000e+01  4.413500e+01  7.763000e+01
# Adj Close  3.549000e+01  4.413500e+01  7.763000e+01
# Volume     1.691305e+07  2.428082e+07  2.692131e+08

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head
# Out:
# <bound method NDFrame.head of             Date       Open       High        Low      Close  Adj Close  \
# 0      11/7/2013  45.099998  50.090000  44.000000  44.900002  44.900002
# 1      11/8/2013  45.930000  46.939999  40.685001  41.650002  41.650002
# 2     11/11/2013  40.500000  43.000000  39.400002  42.900002  42.900002
# 3     11/12/2013  43.660000  43.779999  41.830002  41.900002  41.900002
# 4     11/13/2013  41.029999  42.869999  40.759998  42.599998  42.599998
# ...          ...        ...        ...        ...        ...        ...
# 2259  10/28/2022        NaN        NaN        NaN        NaN        NaN
# 2260  10/31/2022        NaN        NaN        NaN        NaN        NaN
# 2261   11/1/2022        NaN        NaN        NaN        NaN        NaN
# 2262   11/2/2022        NaN        NaN        NaN        NaN        NaN
# 2263   11/3/2022        NaN        NaN        NaN        NaN        NaN
#
#            Volume
# 0     117701670.0
# 1      27925307.0
# 2      16113941.0
# 3       6316755.0
# 4       8688325.0
# ...           ...
# 2259          NaN
# 2260          NaN
# 2261          NaN
# 2262          NaN
# 2263          NaN
#
# [2264 rows x 7 columns]>

# %%
df["Low"].idxmax()
# Out:
# 1838

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0   11/7/2013  45.099998  50.090000  44.000000  44.900002  44.900002
# 1   11/8/2013  45.930000  46.939999  40.685001  41.650002  41.650002
# 2  11/11/2013  40.500000  43.000000  39.400002  42.900002  42.900002
# 3  11/12/2013  43.660000  43.779999  41.830002  41.900002  41.900002
# 4  11/13/2013  41.029999  42.869999  40.759998  42.599998  42.599998
#
#         Volume
# 0  117701670.0
# 1   27925307.0
# 2   16113941.0
# 3    6316755.0
# 4    8688325.0

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2259.000000  2259.000000  2259.000000  2259.000000  2259.000000
# mean     36.020286    36.699881    35.339465    36.003625    36.003625
# std      14.118463    14.372057    13.828724    14.089989    14.089989
# min      13.950000    14.220000    13.725000    14.010000    14.010000
# 25%      25.550000    26.215001    24.912501    25.410000    25.410000
# 50%      35.419998    36.099998    34.820000    35.490002    35.490002
# 75%      44.205000    45.015000    43.327501    44.135000    44.135000
# max      78.360001    80.750000    76.050003    77.629997    77.629997
#
#              Volume
# count  2.259000e+03
# mean   2.175186e+07
# std    1.909988e+07
# min    0.000000e+00
# 25%    1.233530e+07
# 50%    1.691305e+07
# 75%    2.428082e+07
# max    2.692131e+08

# %%
df.sort_values(by="Volume")
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 470    9/22/2015  27.049999  27.480000  26.620001  26.830000  26.830000
# 961     9/1/2017  16.969999  17.000000  16.580000  16.860001  16.860001
# 1795  12/24/2020  54.520000  55.189999  53.857201  53.970001  53.970001
# 15    11/29/2013  41.400002  41.580002  40.900002  41.570000  41.570000
# 517   11/27/2015  25.980000  26.070000  25.670000  25.750000  25.750000
# ...          ...        ...        ...        ...        ...        ...
# 2259  10/28/2022        NaN        NaN        NaN        NaN        NaN
# 2260  10/31/2022        NaN        NaN        NaN        NaN        NaN
# 2261   11/1/2022        NaN        NaN        NaN        NaN        NaN
# 2262   11/2/2022        NaN        NaN        NaN        NaN        NaN
# 2263   11/3/2022        NaN        NaN        NaN        NaN        NaN
#
#          Volume
# 470         0.0
# 961         0.0
# 1795  3661053.0
# 15    4107074.0
# 517   4179967.0
# ...         ...
# 2259        NaN
# 2260        NaN
# 2261        NaN
# 2262        NaN
# 2263        NaN
#
# [2264 rows x 7 columns]

# %% [markdown]
# Visualization

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the closing price over time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'])
plt.title('Twitter Stock Closing Price (2013-2023)')
plt.xlabel('Year')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the closing price over time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Open'])
plt.title('Twitter Stock Closing Price (2013-2023)')
plt.xlabel('Year')
plt.ylabel('Opening Price')
plt.grid(True)
plt.show()

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Plotting the volume over time
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Volume'])
plt.title('Twitter Volumes stock (2013-2023)')
plt.xlabel('Year')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='High', y='Low', data=df)
plt.title('Twitter Stock High vs Low Prices')
plt.xlabel('High Price')
plt.ylabel('Low Price')
plt.show()

# %%
numerical_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap of Twitter Stock Market Data')
plt.show()

# %%
fig, ax = plt.subplots()
ax.set_yscale('log')
ax.hist([df['Open'], df['High'], df['Low'], df['Close']], bins=20, stacked=True, label=['Open', 'High', 'Low', 'Close'])
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
ax.set_title('Stacked Histogram of Twitter Stock Prices')
ax.legend()
plt.show()

# %%
sns.set(style="ticks")
g = sns.JointGrid(data=df, x='Date', y='Close', height=6, ratio=5)
g.plot_joint(sns.scatterplot, color='b')
g.plot_marginals(sns.histplot, kde=True, color='b')
plt.xticks(rotation=45, ha='right')
plt.title('Twitter Stock Close Price Scatterplot with Marginal Ticks')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()
